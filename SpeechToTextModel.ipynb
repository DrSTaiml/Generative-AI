# %%
# To be able to convert text to Speech
! pip install SpeechRecognition 
#To convey the Speech to text and also speak it out
# !pip install gTTS  
# To install our language model
# !pip install transformers  
# !pip install tensorflow
# Out:
# ...
#      ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#      - -------------------------------------- 1.0/32.8 MB 30.4 MB/s eta 0:00:02
#      -- ------------------------------------- 2.3/32.8 MB 29.0 MB/s eta 0:00:02
#      ---- ----------------------------------- 3.8/32.8 MB 30.5 MB/s eta 0:00:01
#      ------ --------------------------------- 5.2/32.8 MB 30.6 MB/s eta 0:00:01
#      ------- -------------------------------- 6.5/32.8 MB 29.5 MB/s eta 0:00:01
#      --------- ------------------------------ 7.7/32.8 MB 29.1 MB/s eta 0:00:01
#      ---------- ----------------------------- 8.9/32.8 MB 28.5 MB/s eta 0:00:01
#      ------------ -------------------------- 10.3/32.8 MB 28.5 MB/s eta 0:00:01
#      ------------- ------------------------- 11.5/32.8 MB 28.4 MB/s eta 0:00:01
#      --------------- ----------------------- 12.8/32.8 MB 27.3 MB/s eta 0:00:01
#      ---------------- ---------------------- 14.0/32.8 MB 26.2 MB/s eta 0:00:01
# ...

# %%
# !pip install pyaudio
# Out:
# ...
#      ---------------------------------------- 0.0/164.1 kB ? eta -:--:--
#      -------------------------------------- 164.1/164.1 kB 4.8 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import speech_recognition as sr

class ChatBot():
    def __init__(self, name):
        print("----- starting up", name, "-----")
        self.name = name
        self.is_listening = True  # Add a flag to control listening

    def speech_to_text(self):
        recognizer = sr.Recognizer()
        with sr.Microphone() as mic:
            print("listening...")
            audio = recognizer.listen(mic)
        try:
            self.text = recognizer.recognize_google(audio)
            print("me --> ", self.text)
            
            # Check if the user said "stop" and stop listening if they did
            if self.text.lower() == "stop":
                self.is_listening = False
        except sr.UnknownValueError:
            print("me -->  ERROR")

    def start_listening(self):
        self.is_listening = True
        while self.is_listening:
            self.speech_to_text()

# Execute the AI
if __name__ == "__main__":
    ai = ChatBot(name="Surabhi")
    ai.start_listening()
# Out:
# ----- starting up Surabhi -----
# listening...
# me -->  hello Kam karo
# listening...
# me -->  stop stop stop
# listening...
# me -->  stop
